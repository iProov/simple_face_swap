# %%
from ipresearch.data.image import Blobs
import matplotlib.pyplot as plt
bs = Blobs("/home/config.json")

# %%
single_token = '9c5176d0c6ef37e73bc85a2e61b01d4f71e0c0a211b1b36c376940371801vi07'
for i in range(20):
    plt.figure()
    img = bs.get_frame(single_token, frame=i, cluster="eu-prod", return_array=True)
    plt.imshow(img)
    plt.show()
