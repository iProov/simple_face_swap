# %%
from ipresearch.data.image import Blobs
import matplotlib.pyplot as plt
bs = Blobs("/home/config.json")

# %%
single_token = '1749f560af6d1bd8dde090d2006712b9b71b6af1154c420160b69db31801vi07'
for i in range(10):
    plt.figure()
    img = bs.get_frame(single_token, frame=i, cluster="eu-prod", return_array=True)
    plt.imshow(img)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1451/2337378321.py in <module>
#       2 for i in range(20):
#       3     plt.figure()
# ----> 4     img = bs.get_frame(single_token, frame=i, cluster="eu-prod", return_array=True)
#       5     plt.imshow(img)
#       6     plt.show()
#
# /usr/local/lib/python3.8/site-packages/ipresearch/data/image.py in get_frame(self, token, cluster, **kwargs)
#     731         if self.active_cluster != cluster:
#     732             self.set_active_blob(cluster)
# --> 733         return self.active_blob.get_frame(token, **kwargs)
#     734
#     735     def get_streamed_frame(self, token, cluster, **kwargs):
#
# /usr/local/lib/python3.8/site-packages/ipresearch/data/image.py in get_frame(self, token, bboxes, rotation, frame, crop, crop_resize, crop_padding, output_dir, return_array, ext, frame_num_postfix, post_process_func)
#     318
#     319         # get frame from video
# --> 320         img = Image.fromarray(video_array[frame - 1])
#     321
#     322         # select, crop, resize, rotate and pad frame
#
# IndexError: index 10 is out of bounds for axis 0 with size 10
